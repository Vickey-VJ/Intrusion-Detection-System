# %%
import streamlit as st
import joblib
import numpy as np
from sklearn.preprocessing import LabelEncoder
from scipy import stats

# Load the trained models
random_forest_model = joblib.load(r'model\random_forest.pkl')
gradient_boosting_model = joblib.load(r'model\gradient_boosting.pkl')
decision_tree_model = joblib.load(r'model\decision_tree.pkl')
naive_bayes_model = joblib.load(r'model\naive_bayes.pkl')

# Set up the Streamlit app layout
st.title("Intrusion Detection System Prediction")
st.write("Select the model and input features to get predictions.")

# Dropdown for model selection
model_choice = st.selectbox("Select the Model", 
                             ["Random Forest", "Gradient Boosting", 
                              "Decision Tree", "Naive Bayes"])

# Input features based on KDD dataset
duration = st.number_input("Duration", value=0.0)
protocol_type = st.selectbox("Protocol Type", ["tcp", "udp", "icmp"])

# Updated flag dropdown
flag = st.selectbox("Flag", ["SF", "S0", "REJ", "RSTR", "RSTO", "SH", "S1", "S2", "RSTOS0", "S3", "OTH"])

src_bytes = st.number_input("Source Bytes", value=0.0)
dst_bytes = st.number_input("Destination Bytes", value=0.0)
land = st.number_input("Land (0 or 1)", value=0)
wrong_fragment = st.number_input("Wrong Fragment", value=0)
urgent = st.number_input("Urgent", value=0)
hot = st.number_input("Hot", value=0)
num_failed_logins = st.number_input("Number of Failed Logins", value=0)
logged_in = st.number_input("Logged In (0 or 1)", value=0)
num_compromised = st.number_input("Number Compromised", value=0)
root_shell = st.number_input("Root Shell (0 or 1)", value=0)
su_attempted = st.number_input("SU Attempted (0 or 1)", value=0)
num_file_creations = st.number_input("Number of File Creations", value=0)
num_shells = st.number_input("Number of Shells", value=0)
num_access_files = st.number_input("Number of Access Files", value=0)
num_outbound_cmds = st.number_input("Number of Outbound Commands", value=0)
is_host_login = st.number_input("Is Host Login (0 or 1)", value=0)
count = st.number_input("Count", value=0)
serror_rate = st.number_input("Service Error Rate", value=0.0)
rerror_rate = st.number_input("Remote Error Rate", value=0.0)
same_srv_rate = st.number_input("Same Service Rate", value=0.0)
diff_srv_rate = st.number_input("Different Service Rate", value=0.0)
srv_diff_host_rate = st.number_input("Service Different Host Rate", value=0.0)
dst_host_count = st.number_input("Destination Host Count", value=0)

dst_host_diff_srv_rate = st.number_input("Destination Host Different Service Rate", value=0.0)
dst_host_same_src_port_rate = st.number_input("Destination Host Same Source Port Rate", value=0.0)
dst_host_srv_diff_host_rate = st.number_input("Destination Host Service Different Host Rate", value=0.0)

# Updated flag mapping
protocol_mapping = {"tcp": 0, "udp": 1, "icmp": 2}
flag_mapping = {
    "SF": 0, "S0": 1, "REJ": 2, "RSTR": 3, "RSTO": 4, "SH": 5, 
    "S1": 6, "S2": 7, "RSTOS0": 8, "S3": 9, "OTH": 10
}

# Convert categorical features to numeric values
protocol_type_encoded = protocol_mapping[protocol_type]
flag_encoded = flag_mapping[flag]

# Create a feature array with all required features (32 features)
features = np.array([[duration, 
                      protocol_type_encoded, 
                      flag_encoded, 
                      src_bytes, 
                      dst_bytes,
                      land, 
                      wrong_fragment, 
                      urgent, 
                      hot, 
                      num_failed_logins, 
                      logged_in, 
                      num_compromised, 
                      root_shell, 
                      su_attempted,
                      num_file_creations,
                      num_shells,
                      num_access_files,
                      num_outbound_cmds,
                      is_host_login,
                      count,
                      serror_rate,
                      rerror_rate,
                      same_srv_rate,
                      diff_srv_rate,
                      srv_diff_host_rate,
                      dst_host_count,
                      dst_host_diff_srv_rate,
                      dst_host_same_src_port_rate,
                      dst_host_srv_diff_host_rate]])

# Ensure the shape of features is correct (1 sample, 32 features)
features = features.reshape(1, -1)

# Mapping the prediction output to specific attack types from the KDD dataset
attack_types = {0: 'back._dos', 
                1: 'buffer_overflow._u2r',
                2: 'ftp_write._r2l',
                3: 'guess_passwd._r2l',
                4: 'imap._r2l',
                5: 'ipsweep._probe',
                6: 'land._dos',
                7: 'loadmodule._u2r',
                8: 'multihop._r2l',
                9: 'neptune._dos',
                10: 'nmap._probe',
                11: 'normal._normal',
                12: 'perl._u2r',
                13: 'phf._r2l',
                14: 'pod._dos',
                15: 'portsweep._probe',
                16: 'rootkit._u2r',
                17: 'satan._probe',
                18: 'smurf._dos',
                19: 'spy._r2l',
                20: 'teardrop._dos',
                21: 'warezclient._r2l',
                22: 'warezmaster._r2l'}

# Make predictions based on the selected model
if st.button("Predict"):
    try:
        # Get predictions from the selected model
        if model_choice == "Random Forest":
            model = random_forest_model
        elif model_choice == "Gradient Boosting":
            model = gradient_boosting_model
        elif model_choice == "Decision Tree":
            model = decision_tree_model
        elif model_choice == "Naive Bayes":
            model = naive_bayes_model

        # Make prediction
        prediction = model.predict(features)[0]

        # Map the prediction to the attack type
        attack_prediction = attack_types.get(prediction, 'Unknown')

        # Determine the category of the attack
        attack_category = "Normal" if prediction == 11 else "Attack"
        
        # Display the prediction result
        st.write(f"**Prediction Index:** {prediction}")
        st.write(f"**Attack Type:** {attack_prediction}")
        st.write(f"**Attack Category:** {attack_category}")

    except Exception as e:
        st.error(f"An error occurred: {str(e)}")
# Out:
# 2024-11-09 22:39:39.417 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.132
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\WIN\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-09 22:39:40.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.141 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.144 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.152 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.152 Session state does not function when running a script without `streamlit run`
# 2024-11-09 22:39:40.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.158 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.168 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.184 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.197 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.199 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.202 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.205 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.209 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.215 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.216 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.218 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.224 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.226 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.233 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.236 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.239 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.242 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.247 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.254 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.258 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.260 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.264 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.267 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.269 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.271 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.273 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.280 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.289 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.296 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.302 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.315 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.341 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.351 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.370 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.375 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.377 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.378 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.384 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.387 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.390 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.391 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.392 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.394 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.403 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.405 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.408 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.415 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.421 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.422 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.423 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.425 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.430 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.434 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.448 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.449 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.450 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.451 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.452 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.453 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.454 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.455 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.456 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.458 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.464 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.466 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.467 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.468 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.469 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.470 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.471 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.472 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.474 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.475 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.477 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.480 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.483 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.485 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.486 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.487 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.489 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.490 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.496 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.498 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.502 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.503 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.504 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.505 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.506 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.507 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.510 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.514 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.516 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.517 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.518 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.520 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.521 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.522 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.523 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.525 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.526 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.535 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.537 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.541 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.547 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-09 22:39:40.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# Load the trained models
random_forest_model = joblib.load(r'model\random_forest_model.pkl')
gradient_boosting_model = joblib.load(r'model\gradient_boosting_model.pkl')
decision_tree_model = joblib.load(r'model\decision_tree_model.pkl')
naive_bayes_model = joblib.load(r'model\naive_bayes_model.pkl')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Load the trained models
# ----> 2 random_forest_model = joblib.load(r'model\random_forest_model.pkl')
#       3 gradient_boosting_model = joblib.load(r'model\gradient_boosting_model.pkl')
#       4 decision_tree_model = joblib.load(r'model\decision_tree_model.pkl')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\joblib\numpy_pickle.py:650, in load(filename, mmap_mode)
#     648         obj = _unpickle(fobj)
#     649 else:
# --> 650     with open(filename, 'rb') as f:
#     651         with _read_fileobject(f, filename, mmap_mode) as fobj:
#     652             if isinstance(fobj, str):
#     653                 # if the returned file object is a string, this means we
#     654                 # try to load a pickle file generated with an version of
#     655                 # Joblib so we load it with joblib compatibility function.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'model\\random_forest_model.pkl'
